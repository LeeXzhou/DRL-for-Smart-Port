# %%
### This script is used to run the SmartPort environment 
### on a remote server without a display through SSH.

from src.env.smart_port import SmartPort
from src.utils.logger import log

env = SmartPort()

state, env_param = env.reset()

env.render()
# env.render(use_pygame=True)
# Out:
# The env parameter in file `src/env/conf.toml` needs to be completed.
